# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
import datetime
from datetime import timedelta
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.min_rows', 30)
pd.set_option('display.max_rows',100)
pd.set_option('display.width', 1000)

def general_plot(x_, y_, x_bounds = None, y_bounds = None, title = None, x_title = None, y_title = None):
    fig, ax = plt.subplots(figsize=(15, 4))

    plt.xticks(rotation=90)
    plt.grid(True)
    
    if title is not None:
        plt.title(title)
    
    if x_title is not None:    
        plt.xlabel(x_title)
        
    if y_title is not None:    
        plt.ylabel(y_title)
    
    if (x_bounds is not None):
        plt.xlim(x_bounds)
               
    if (y_bounds is not None):
        plt.ylim(y_bounds)
    ax.plot(x_,y_, 'bo')
    
    plt.show()
    
# Useful classes to have easier access to data features
class ColumnsInput:
    barcode = 'ddc_barcode'
    ipcode = 'ddc_ipcode'
    machine = 'ddc_mch_code'
    machine_side = 'ddc_mch_side'
    event = 'ddc_ev_subcode'
    time = 'ddc_ev_timestamp'
    
    
class ColumnsOutput:
    c_machine = 'c_machine' 
    event_delta_time = 'event_delta_time'
    day = 'y-m-day'
    month = 'month'
    status = 'status'

# %%
df=pd.read_csv("Data/preprocessed_data_2021.csv", low_memory=False)

# %%
df[ColumnsInput.time] = pd.to_datetime(df[ColumnsInput.time])
df[ColumnsOutput.status] = "False"

# %%
df.sort_values(ColumnsInput.time).groupby(ColumnsInput.barcode)[ColumnsInput.event].agg(['first','last']).value_counts()
# Out:
# first                   last
# LO_LOADER_IN_PRESS      UN_FORK_OUT               17533
#                         UN_UNLOADER_OUT            9427
#                         UN_TCR_DOWN                 770
#                         UN_TCR_UP_LMR_DOWN          258
#                         OP_PRESS_LOCKED              37
#                         UN_UNLOADER_UP               24
#                         OP_UNLOCK_PRESS              19
#                         CURING_OFF                   14
#                         UN_TCR_UP_NO_SUV             12
#                         UN_VACUUM                     9
# CURING_OFF              CURING_ON                     8
# UN_FORK_OUT             UN_TCR_DOWN                   7
# LO_LOADER_IN_PRESS      UN_SWING_IN_ARMS              7
#                         OP_SQUEEZE_OFF                6
# UN_VACUUM               UN_FORK_OUT                   5
# LO_LOADER_IN_PRESS      OP_PRESS_MOVEMENT_UP_2        4
#                         OP_PRESS_MOVEMENT_UP_3        4
#                         CL_PRESS_LOCK                 3
#                         LO_TCR_DOWN                   3
#                         OP_PRESS_STOP_PAUSE_3         3
#                         UN_LMR_TCR_VACUUM             2
# LO_LOADER_RELEASE_TIRE  UN_FORK_OUT                   2
# OP_PRESS_MOVEMENT_UP_1  UN_FORK_OUT                   2
# LO_LOADER_IN_PRESS      UN_CLOSE_ARMS                 2
# OP_PRESS_STOP_PAUSE_3   UN_FORK_OUT                   2
# CL_PRESS_DOWN           UN_FORK_OUT                   2
# LO_LOADER_IN_PRESS      OP_PRESS_MOVEMENT_UP_1        2
#                         LO_LOADER_DOWN                2
#                         LO_BLADDER_VACUUM             2
#                         CL_PRESS_DOWN_3               2
# CURING_OFF              UN_FORK_OUT                   2
# LO_LOADER_IN_PRESS      OP_PRESS_STOP_PAUSE_2         1
# LO_BLADDER_PRESHAPING   UN_FORK_OUT                   1
# CL_PRESS_DOWN_3         UN_UNLOADER_OUT               1
# UN_CLOSE_ARMS           UN_UNLOADER_OUT               1
# CL_UNLOCK_PRESS         UN_UNLOADER_OUT               1
# LO_LOADER_UP            UN_FORK_OUT                   1
# LO_LOADER_IN_PRESS      CL_PRESS_DOWN                 1
# LO_BLADDER_PRESHAPING   UN_UNLOADER_OUT               1
# LO_BLADDER_VACUUM       UN_UNLOADER_OUT               1
# CL_PRESS_DOWN           UN_UNLOADER_OUT               1
# LO_LOADER_IN_PRESS      CURING_ON                     1
#                         UN_LMR_UP                     1
#                         LO_PRESHAPING                 1
#                         OP_PRESS_STOP_PAUSE_1         1
# Name: count, dtype: int64

# %%
last_indexes = df.sort_values(ColumnsInput.time).groupby(ColumnsInput.barcode)[ColumnsInput.event].agg(['last']).reset_index()
first_indexes = df.sort_values(ColumnsInput.time).groupby(ColumnsInput.barcode)[ColumnsInput.event].agg('first').reset_index()
first_last_indexes = df.sort_values(ColumnsInput.time).groupby(ColumnsInput.barcode)[ColumnsInput.event].agg(['first', 'last']).reset_index()
print(len(last_indexes))
print(len(first_indexes))
first_last_indexes
# Out:
# 28189
# 28189
#        ddc_barcode               first                last
# 0       9430887732  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 1       9430887737  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 2       9430888020  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 3       9430890266  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 4       9430890274  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 5       9430890277  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 6       9435411478  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 7       9435411953  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 8       9435411967  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 9       9435411976  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 10      9435411977  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 11      9435411978  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 12      9435411981  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 13      9435411982  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# 14      9435411983  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT
# ...            ...                 ...                 ...
# 28174   9437400510  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28175   9437400547  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28176   9437400548  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28177   9437400549  LO_LOADER_IN_PRESS  UN_TCR_UP_LMR_DOWN
# 28178   9437400550  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28179   9437400551  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28180   9437400552  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28181   9437400553  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28182   9437400554  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28183   9437400555  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28184   9437400556  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28185   9437400557  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28186   9437400558  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28187   9437400559  LO_LOADER_IN_PRESS         UN_FORK_OUT
# 28188   9437400560  LO_LOADER_IN_PRESS         UN_FORK_OUT
#
# [28189 rows x 3 columns]

# %%
first_last_indexes[ColumnsOutput.status] = False
print(first_last_indexes.columns)
starting_event = ["LO_LOADER_IN_PRESS", "LO_LOADER_IN_PRESS_START"]
ending_event = ["UN_UNLOADER_OUT", "UN_FORK_OUT", "UN_UNLOADER_OUT_STOP", "UN_FORK_OUT_STOP"]

first_last_indexes[ColumnsOutput.status] = first_last_indexes.apply(lambda x: 'CYCLE_COMPLETED' if x['last'] in ending_event else 'CYCLE_ABORTED' if x['first'] in starting_event else 'CYCLE_NOT_STARTED', axis=1)
first_last_indexes.value_counts(ColumnsOutput.status)
first_last_indexes
# Out:
# Index(['ddc_barcode', 'first', 'last', 'status'], dtype='object')
#        ddc_barcode               first                last           status
# 0       9430887732  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 1       9430887737  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 2       9430888020  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 3       9430890266  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 4       9430890274  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 5       9430890277  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 6       9435411478  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 7       9435411953  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 8       9435411967  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 9       9435411976  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 10      9435411977  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 11      9435411978  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 12      9435411981  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 13      9435411982  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# 14      9435411983  LO_LOADER_IN_PRESS     UN_UNLOADER_OUT  CYCLE_COMPLETED
# ...            ...                 ...                 ...              ...
# 28174   9437400510  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28175   9437400547  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28176   9437400548  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28177   9437400549  LO_LOADER_IN_PRESS  UN_TCR_UP_LMR_DOWN    CYCLE_ABORTED
# 28178   9437400550  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28179   9437400551  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28180   9437400552  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28181   9437400553  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28182   9437400554  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28183   9437400555  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28184   9437400556  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28185   9437400557  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28186   9437400558  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28187   9437400559  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
# 28188   9437400560  LO_LOADER_IN_PRESS         UN_FORK_OUT  CYCLE_COMPLETED
#
# [28189 rows x 4 columns]

# %%
set_cycle = first_last_indexes.groupby(ColumnsOutput.status)[ColumnsInput.barcode].unique() #9430887732ù
del first_last_indexes
df[ColumnsOutput.status] = df.apply(lambda x: 'CYCLE_COMPLETED' if x[ColumnsInput.barcode] in set_cycle['CYCLE_COMPLETED'] else 'CYCLE_ABORTED' if x[ColumnsInput.barcode] in set_cycle['CYCLE_ABORTED'] else 'CYCLE_NOT_STARTED', axis=1)
df
# Out:
#         Unnamed: 0  ddc_barcode  ddc_ipcode ddc_mch_code ddc_mch_side          ddc_ev_subcode    ddc_ev_timestamp  c_machine  month   y-m-day           status
# 0                0   9436800087       37887         1305            R      LO_LOADER_IN_PRESS 2021-12-17 09:15:23      False     12  21-12-17    CYCLE_ABORTED
# 1                1   9436800087       37887         1305            R       LO_BLADDER_VACUUM 2021-12-17 09:15:27      False     12  21-12-17    CYCLE_ABORTED
# 2                2   9436800087       37887         1305            R   LO_BLADDER_PRESHAPING 2021-12-17 09:15:27      False     12  21-12-17    CYCLE_ABORTED
# 3                3   9436800087       37887         1305            R          LO_LOADER_DOWN 2021-12-17 09:15:34      False     12  21-12-17    CYCLE_ABORTED
# 4                4   9436800087       37887         1305            R             LO_TCR_DOWN 2021-12-17 09:15:38      False     12  21-12-17    CYCLE_ABORTED
# 5                5   9436800087       37887         1305            R           LO_PRESHAPING 2021-12-17 09:15:41      False     12  21-12-17    CYCLE_ABORTED
# 6                6   9436800087       37887         1305            R            LO_LOADER_UP 2021-12-17 09:15:56      False     12  21-12-17    CYCLE_ABORTED
# 7                7   9436800087       37887         1305            R  LO_LOADER_RELEASE_TIRE 2021-12-17 09:15:56      False     12  21-12-17    CYCLE_ABORTED
# 8                8   9436800087       37887         1305            R           LO_LOADER_OUT 2021-12-17 09:15:58      False     12  21-12-17    CYCLE_ABORTED
# 9                9   9436800087       37887         1305            R         CL_UNLOCK_PRESS 2021-12-17 09:16:02      False     12  21-12-17    CYCLE_ABORTED
# 10              10   9436800087       37887         1305            R           CL_PRESS_DOWN 2021-12-17 09:16:04      False     12  21-12-17    CYCLE_ABORTED
# 11              11   9436800087       37887         1305            R           CL_STOP_PAUSE 2021-12-17 09:16:10      False     12  21-12-17    CYCLE_ABORTED
# 12              12   9436800087       37887         1305            R         CL_PRESS_DOWN_2 2021-12-17 09:16:10      False     12  21-12-17    CYCLE_ABORTED
# 13              13   9436800087       37887         1305            R         CL_STOP_PAUSE_2 2021-12-17 09:16:12      False     12  21-12-17    CYCLE_ABORTED
# 14              14   9436800087       37887         1305            R         CL_PRESS_DOWN_3 2021-12-17 09:16:22      False     12  21-12-17    CYCLE_ABORTED
# ...            ...          ...         ...          ...          ...                     ...                 ...        ...    ...       ...              ...
# 972983       73927   9437389899       25352         C111            R   OP_PRESS_STOP_PAUSE_1 2021-12-21 14:02:15       True     12  21-12-21  CYCLE_COMPLETED
# 972984       73928   9437389899       25352         C111            R  OP_PRESS_MOVEMENT_UP_1 2021-12-21 14:02:20       True     12  21-12-21  CYCLE_COMPLETED
# 972985       73929   9437389899       25352         C111            R   OP_PRESS_STOP_PAUSE_2 2021-12-21 14:02:21       True     12  21-12-21  CYCLE_COMPLETED
# 972986       73930   9437389899       25352         C111            R  OP_PRESS_MOVEMENT_UP_2 2021-12-21 14:02:26       True     12  21-12-21  CYCLE_COMPLETED
# 972987       73931   9437389899       25352         C111            R         OP_PRESS_LOCKED 2021-12-21 14:02:35       True     12  21-12-21  CYCLE_COMPLETED
# 972988       73932   9437389899       25352         C111            R       UN_SWING_POSITION 2021-12-21 14:02:35       True     12  21-12-21  CYCLE_COMPLETED
# 972989       73933   9437389899       25352         C111            R       UN_LMR_TCR_VACUUM 2021-12-21 14:02:37       True     12  21-12-21  CYCLE_COMPLETED
# 972990       73934   9437389899       25352         C111            R        UN_SWING_IN_ARMS 2021-12-21 14:02:47       True     12  21-12-21  CYCLE_COMPLETED
# 972991       73935   9437389899       25352         C111            R               UN_TCR_UP 2021-12-21 14:03:00       True     12  21-12-21  CYCLE_COMPLETED
# 972992       73936   9437389899       25352         C111            R        UN_UNLOADER_DOWN 2021-12-21 14:03:00       True     12  21-12-21  CYCLE_COMPLETED
# 972993       73937   9437389899       25352         C111            R           UN_CLOSE_ARMS 2021-12-21 14:03:03       True     12  21-12-21  CYCLE_COMPLETED
# 972994       73938   9437389899       25352         C111            R            UN_OPEN_ARMS 2021-12-21 14:03:06       True     12  21-12-21  CYCLE_COMPLETED
# 972995       73939   9437389899       25352         C111            R        UN_TCR_UP_NO_SUV 2021-12-21 14:03:07       True     12  21-12-21  CYCLE_COMPLETED
# 972996       73940   9437389899       25352         C111            R          UN_UNLOADER_UP 2021-12-21 14:03:07       True     12  21-12-21  CYCLE_COMPLETED
# 972997       73941   9437389899       25352         C111            R         UN_UNLOADER_OUT 2021-12-21 14:03:11       True     12  21-12-21  CYCLE_COMPLETED
#
# [972998 rows x 11 columns]

# %%
aborted_jobs = df[df[ColumnsOutput.status] == 'CYCLE_ABORTED']
print(aborted_jobs)
save_df = df.to_csv('Data/label_preprocessed_data_2021.csv', index=False)
save_aborts = aborted_jobs.to_csv('Data/aborted_jobs_2022.csv', index=False)
# Out:
#         Unnamed: 0  ddc_barcode  ddc_ipcode ddc_mch_code ddc_mch_side          ddc_ev_subcode    ddc_ev_timestamp  c_machine  month   y-m-day         status
# 0                0   9436800087       37887         1305            R      LO_LOADER_IN_PRESS 2021-12-17 09:15:23      False     12  21-12-17  CYCLE_ABORTED
# 1                1   9436800087       37887         1305            R       LO_BLADDER_VACUUM 2021-12-17 09:15:27      False     12  21-12-17  CYCLE_ABORTED
# 2                2   9436800087       37887         1305            R   LO_BLADDER_PRESHAPING 2021-12-17 09:15:27      False     12  21-12-17  CYCLE_ABORTED
# 3                3   9436800087       37887         1305            R          LO_LOADER_DOWN 2021-12-17 09:15:34      False     12  21-12-17  CYCLE_ABORTED
# 4                4   9436800087       37887         1305            R             LO_TCR_DOWN 2021-12-17 09:15:38      False     12  21-12-17  CYCLE_ABORTED
# 5                5   9436800087       37887         1305            R           LO_PRESHAPING 2021-12-17 09:15:41      False     12  21-12-17  CYCLE_ABORTED
# 6                6   9436800087       37887         1305            R            LO_LOADER_UP 2021-12-17 09:15:56      False     12  21-12-17  CYCLE_ABORTED
# 7                7   9436800087       37887         1305            R  LO_LOADER_RELEASE_TIRE 2021-12-17 09:15:56      False     12  21-12-17  CYCLE_ABORTED
# 8                8   9436800087       37887         1305            R           LO_LOADER_OUT 2021-12-17 09:15:58      False     12  21-12-17  CYCLE_ABORTED
# 9                9   9436800087       37887         1305            R         CL_UNLOCK_PRESS 2021-12-17 09:16:02      False     12  21-12-17  CYCLE_ABORTED
# 10              10   9436800087       37887         1305            R           CL_PRESS_DOWN 2021-12-17 09:16:04      False     12  21-12-17  CYCLE_ABORTED
# 11              11   9436800087       37887         1305            R           CL_STOP_PAUSE 2021-12-17 09:16:10      False     12  21-12-17  CYCLE_ABORTED
# 12              12   9436800087       37887         1305            R         CL_PRESS_DOWN_2 2021-12-17 09:16:10      False     12  21-12-17  CYCLE_ABORTED
# 13              13   9436800087       37887         1305            R         CL_STOP_PAUSE_2 2021-12-17 09:16:12      False     12  21-12-17  CYCLE_ABORTED
# 14              14   9436800087       37887         1305            R         CL_PRESS_DOWN_3 2021-12-17 09:16:22      False     12  21-12-17  CYCLE_ABORTED
# ...            ...          ...         ...          ...          ...                     ...                 ...        ...    ...       ...            ...
# 971516       72460   9437389943       25352         C105            L           CL_STOP_PAUSE 2021-12-21 12:51:50       True     12  21-12-21  CYCLE_ABORTED
# 971517       72461   9437389943       25352         C105            L         CL_STOP_PAUSE_2 2021-12-21 12:51:50       True     12  21-12-21  CYCLE_ABORTED
# 971533       72477   9437389943       25352         C105            L         CL_PRESS_DOWN_3 2021-12-21 12:52:05       True     12  21-12-21  CYCLE_ABORTED
# 971549       72493   9437389943       25352         C105            L           CL_PRESS_LOCK 2021-12-21 12:52:18       True     12  21-12-21  CYCLE_ABORTED
# 971550       72494   9437389943       25352         C105            L           CL_SQUEEZE_ON 2021-12-21 12:52:18       True     12  21-12-21  CYCLE_ABORTED
# 971561       72505   9437389943       25352         C105            L               CURING_ON 2021-12-21 12:52:26       True     12  21-12-21  CYCLE_ABORTED
# 972136       73080   9437389943       25352         C105            L              CURING_OFF 2021-12-21 13:10:25       True     12  21-12-21  CYCLE_ABORTED
# 972137       73081   9437389943       25352         C105            L  OP_PRESS_MOVEMENT_UP_3 2021-12-21 13:10:25       True     12  21-12-21  CYCLE_ABORTED
# 972138       73082   9437389943       25352         C105            L   OP_PRESS_STOP_PAUSE_3 2021-12-21 13:10:25       True     12  21-12-21  CYCLE_ABORTED
# 972178       73122   9437389943       25352         C105            L              UN_FORK_IN 2021-12-21 13:11:07       True     12  21-12-21  CYCLE_ABORTED
# 972179       73123   9437389943       25352         C105            L               UN_LMR_UP 2021-12-21 13:11:07       True     12  21-12-21  CYCLE_ABORTED
# 972186       73130   9437389943       25352         C105            L         OP_PRESS_LOCKED 2021-12-21 13:11:09       True     12  21-12-21  CYCLE_ABORTED
# 972191       73135   9437389943       25352         C105            L               UN_VACUUM 2021-12-21 13:11:12       True     12  21-12-21  CYCLE_ABORTED
# 972211       73155   9437389943       25352         C105            L      UN_TCR_UP_LMR_DOWN 2021-12-21 13:11:32       True     12  21-12-21  CYCLE_ABORTED
# 972218       73162   9437389943       25352         C105            L             UN_TCR_DOWN 2021-12-21 13:11:40       True     12  21-12-21  CYCLE_ABORTED
#
# [38587 rows x 11 columns]
